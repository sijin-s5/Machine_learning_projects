# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('spam_email_dataset.csv')
df
# Out:
#                              Email  \
# 0            mikerusso@example.net
# 1          waynebailey@example.org
# 2               jill43@example.com
# 3         johnsonkaren@example.org
# 4           markwilson@example.org
# ...                            ...
# 5995     cassidytaylor@example.com
# 5996          lisatate@example.com
# 5997  cassandravazquez@example.org
# 5998            amoore@example.com
# 5999         vwilliams@example.org
#
#                                                 Subject  \
# 0                          Even hotel community church.
# 1     Try themselves guess fight white agreement thu...
# 2     Environmental commercial off seem any conference.
# 3         Smile real TV father commercial day increase.
# 4                        Fast stage he oil institution.
# ...                                                 ...
# 5995            Current team yet like realize American.
# 5996       Also start certainly range great try others.
# ...

# %%
df.head()
# Out:
#                       Email  \
# 0     mikerusso@example.net
# 1   waynebailey@example.org
# 2        jill43@example.com
# 3  johnsonkaren@example.org
# 4    markwilson@example.org
#
#                                              Subject  \
# 0                       Even hotel community church.
# 1  Try themselves guess fight white agreement thu...
# 2  Environmental commercial off seem any conference.
# 3      Smile real TV father commercial day increase.
# 4                     Fast stage he oil institution.
#
#                      Sender                   Recipient        Date   Time  \
# 0    emilyscott@example.org    gregorysmith@example.org  13-02-2023  04:13
# 1      annwhite@example.net  gonzalezdaniel@example.net  09-08-2023  06:15
# 2       david88@example.net   michellebaker@example.net  16-05-2023  01:32
# 3  lindaalvarez@example.com   schroedertodd@example.com  25-04-2023  14:50
# 4     vstafford@example.com   emilywilliams@example.com  11-07-2023  21:44
#
# ...

# %%
df.tail()
# Out:
#                              Email  \
# 5995     cassidytaylor@example.com
# 5996          lisatate@example.com
# 5997  cassandravazquez@example.org
# 5998            amoore@example.com
# 5999         vwilliams@example.org
#
#                                            Subject  \
# 5995       Current team yet like realize American.
# 5996  Also start certainly range great try others.
# 5997                Matter issue win agent likely.
# 5998                          Again member father.
# 5999       Position recognize behind boy try able.
#
#                           Sender                      Recipient        Date  \
# 5995  martinezangela@example.net     perkinsmatthew@example.org  10-04-2023
# 5996   mckenzieerika@example.net           jeremy75@example.org  07-05-2023
# 5997          dlewis@example.org  cervanteskimberly@example.org  08-04-2023
# 5998          eperry@example.org             dana02@example.org  19-01-2023
# ...

# %%
df.shape
# Out:
# (6000, 16)

# %%
df.isna().sum()
# Out:
# Email                0
# Subject              0
# Sender               0
# Recipient            0
# Date                 0
# Time                 0
# Attachments          0
# Link Count           0
# Word Count           0
# Uppercase Count      0
# Exclamation Count    0
# Question Count       0
# Dollar Count         0
# Punctuation Count    0
# HTML Tags Count      0
# Spam Indicator       0
# dtype: int64

# %%
df.describe()
# Out:
#        Attachments   Link Count   Word Count  Uppercase Count  \
# count  6000.000000  6000.000000  6000.000000      6000.000000
# mean      1.497833     5.005500   153.269500        75.997667
# std       1.125555     3.166092    83.135747        64.735568
# min       0.000000     0.000000    10.000000         0.000000
# 25%       0.000000     2.000000    83.000000        23.000000
# 50%       1.000000     5.000000   154.000000        59.000000
# 75%       3.000000     8.000000   223.000000       114.000000
# max       3.000000    10.000000   300.000000       300.000000
#
#        Exclamation Count  Question Count  Dollar Count  Punctuation Count  \
# count        6000.000000     6000.000000   6000.000000        6000.000000
# mean            2.481833        1.486000      0.989500           7.549667
# std             1.717895        1.118785      0.812301           4.624619
# min             0.000000        0.000000      0.000000           0.000000
# ...

# %%
df.dtypes
# Out:
# Email                object
# Subject              object
# Sender               object
# Recipient            object
# Date                 object
# Time                 object
# Attachments           int64
# Link Count            int64
# Word Count            int64
# Uppercase Count       int64
# Exclamation Count     int64
# Question Count        int64
# Dollar Count          int64
# Punctuation Count     int64
# HTML Tags Count       int64
# Spam Indicator        int64
# dtype: object

# %%
df['Spam Indicator'].value_counts()    #so it is balanced dataset
# Out:
# Spam Indicator
# 0    3018
# 1    2982
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
corr=df.corr(numeric_only=True)
sns.heatmap(corr,cmap='coolwarm',annot=True,linewidths=0.5)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Email', 'Subject', 'Sender', 'Recipient', 'Date', 'Time',
#        'Attachments', 'Link Count', 'Word Count', 'Uppercase Count',
#        'Exclamation Count', 'Question Count', 'Dollar Count',
#        'Punctuation Count', 'HTML Tags Count', 'Spam Indicator'],
#       dtype='object')

# %%
df.drop(columns=['Email','Subject','Sender','Recipient','Date','Time','Word Count',],axis=1,inplace=True)

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)
x_train
# Out:
# array([[-1.33419826, -0.31723201,  0.35014091, ..., -1.20002222,
#          0.09483051, -0.30593947],
#        [-0.44416765,  0.31407547,  0.65918942, ...,  1.27000637,
#          1.17890277, -1.48316875],
#        [ 1.33589355,  0.62972921,  1.33909612, ...,  1.27000637,
#          1.17890277, -0.89455411],
#        ...,
#        [-1.33419826,  0.62972921,  0.96823792, ...,  0.03499207,
#          1.39571722,  0.87128982],
#        [-0.44416765,  0.94538296, -0.96331521, ...,  0.03499207,
#          0.74527387, -0.30593947],
#        [ 1.33589355,  0.94538296,  2.54438527, ...,  1.27000637,
#         -1.42287065,  0.28267517]], shape=(4200, 8))

# %%
#Model selection
from sklearn.svm import SVC
model=SVC()
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 1, 1, 1], shape=(1800,))

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.5188888888888888
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.53      0.51      0.52       926
#            1       0.50      0.53      0.52       874
#
#     accuracy                           0.52      1800
#    macro avg       0.52      0.52      0.52      1800
# weighted avg       0.52      0.52      0.52      1800
#
#
# Confusion Matrix:
#  [[469 457]
#  [409 465]]
