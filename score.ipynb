# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('Exam_Score_Prediction.csv')
df
# Out:
#        student_id  age  gender   course  study_hours  class_attendance  \
# 0               1   17    male  diploma         2.78              92.9
# 1               2   23   other      bca         3.37              64.8
# 2               3   22    male     b.sc         7.88              76.8
# 3               4   20   other  diploma         0.67              48.4
# 4               5   20  female  diploma         0.89              71.6
# ...           ...  ...     ...      ...          ...               ...
# 19995       19997   18   other      bba         6.50              71.3
# 19996       19998   18    male    b.com         3.71              41.6
# 19997       19999   19   other  diploma         7.88              68.2
# 19998       20000   19    male      bba         4.60              76.3
# 19999       20001   20    male     b.sc         7.50              47.9
#
#       internet_access  sleep_hours sleep_quality   study_method  \
# ...

# %%
df.head()
# Out:
#    student_id  age  gender   course  study_hours  class_attendance  \
# 0           1   17    male  diploma         2.78              92.9
# 1           2   23   other      bca         3.37              64.8
# 2           3   22    male     b.sc         7.88              76.8
# 3           4   20   other  diploma         0.67              48.4
# 4           5   20  female  diploma         0.89              71.6
#
#   internet_access  sleep_hours sleep_quality   study_method facility_rating  \
# 0             yes          7.4          poor       coaching             low
# 1             yes          4.6       average  online videos          medium
# 2             yes          8.5          poor       coaching            high
# 3             yes          5.8       average  online videos             low
# 4             yes          9.8          poor       coaching             low
#
#   exam_difficulty  exam_score
# 0            hard        58.9
# 1        moderate        54.8
# ...

# %%
df.tail()
# Out:
#        student_id  age gender   course  study_hours  class_attendance  \
# 19995       19997   18  other      bba         6.50              71.3
# 19996       19998   18   male    b.com         3.71              41.6
# 19997       19999   19  other  diploma         7.88              68.2
# 19998       20000   19   male      bba         4.60              76.3
# 19999       20001   20   male     b.sc         7.50              47.9
#
#       internet_access  sleep_hours sleep_quality study_method facility_rating  \
# 19995             yes          5.0          good   self-study             low
# 19996              no          5.9       average     coaching          medium
# 19997             yes          4.6          poor  group study             low
# 19998              no          6.1          good   self-study          medium
# 19999             yes          7.5          poor     coaching          medium
#
#       exam_difficulty  exam_score
# 19995            easy        86.5
# ...

# %%
df.shape
# Out:
# (20000, 13)

# %%
df.dtypes
# Out:
# student_id            int64
# age                   int64
# gender               object
# course               object
# study_hours         float64
# class_attendance    float64
# internet_access      object
# sleep_hours         float64
# sleep_quality        object
# study_method         object
# facility_rating      object
# exam_difficulty      object
# exam_score          float64
# dtype: object

# %%
df.isna().sum()
# Out:
# student_id          0
# age                 0
# gender              0
# course              0
# study_hours         0
# class_attendance    0
# internet_access     0
# sleep_hours         0
# sleep_quality       0
# study_method        0
# facility_rating     0
# exam_difficulty     0
# exam_score          0
# dtype: int64

# %%
df.drop(columns=['student_id','age','gender'],inplace=True)

# %%
df['course'].unique()
# Out:
# array(['diploma', 'bca', 'b.sc', 'b.tech', 'bba', 'ba', 'b.com'],
#       dtype=object)

# %%
df['study_method'].unique()
# Out:
# array(['coaching', 'online videos', 'mixed', 'self-study', 'group study'],
#       dtype=object)

# %%
df.dtypes
# Out:
# course               object
# study_hours         float64
# class_attendance    float64
# internet_access      object
# sleep_hours         float64
# sleep_quality        object
# study_method         object
# facility_rating      object
# exam_difficulty      object
# exam_score          float64
# dtype: object

# %%
df.columns
# Out:
# Index(['course', 'study_hours', 'class_attendance', 'internet_access',
#        'sleep_hours', 'sleep_quality', 'study_method', 'facility_rating',
#        'exam_difficulty', 'exam_score'],
#       dtype='object')

# %%
lst=['course','internet_access','sleep_quality','study_method','facility_rating','exam_difficulty']
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()
for i in lst:
 df[i]=lab.fit_transform(df[i])

# %%
df
# Out:
#        course  study_hours  class_attendance  internet_access  sleep_hours  \
# 0           6         2.78              92.9                1          7.4
# 1           5         3.37              64.8                1          4.6
# 2           1         7.88              76.8                1          8.5
# 3           6         0.67              48.4                1          5.8
# 4           6         0.89              71.6                1          9.8
# ...       ...          ...               ...              ...          ...
# 19995       4         6.50              71.3                1          5.0
# 19996       0         3.71              41.6                0          5.9
# 19997       6         7.88              68.2                1          4.6
# 19998       4         4.60              76.3                0          6.1
# 19999       1         7.50              47.9                1          7.5
#
# ...

# %%
plt.figure(figsize=(10,8))
corr=df.corr(numeric_only=True)
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.show()

# %%
df.drop(columns=['course','internet_access','facility_rating','exam_difficulty'],inplace=True)

# %%
df.columns
# Out:
# Index(['study_hours', 'class_attendance', 'sleep_hours', 'sleep_quality',
#        'study_method', 'exam_score'],
#       dtype='object')

# %%
x=df.drop(columns=['exam_score']).values
y=df['exam_score'].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)
x_train
# Out:
# array([[ 6.87, 57.1 ,  9.  ,  1.  ,  1.  ],
#        [ 6.91, 54.8 ,  9.1 ,  1.  ,  2.  ],
#        [ 5.45, 99.4 ,  7.6 ,  0.  ,  1.  ],
#        ...,
#        [ 1.49, 80.1 ,  7.1 ,  1.  ,  2.  ],
#        [ 0.28, 52.1 ,  7.1 ,  1.  ,  3.  ],
#        [ 0.59, 67.6 ,  9.1 ,  1.  ,  0.  ]], shape=(16000, 5))

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
scalar.fit(x_train)
x_train=scalar.transform(x_train)
x_test=scalar.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([37.96449716, 69.59876767, 52.73664805, ..., 63.22363509,
#        68.48478093, 48.49614238], shape=(4000,))

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error,root_mean_squared_error,r2_score
mae=mean_absolute_error(y_test,y_pred)
mape=mean_absolute_percentage_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=root_mean_squared_error(y_test,y_pred)
r2_scor=r2_score(y_test,y_pred)
mae
# Out:
# 8.868736093859523

# %%
mape
# Out:
# 0.16710752932216957

# %%
mse
# Out:
# 120.97728694706024

# %%
rmse
# Out:
# 10.998967540049394

# %%
r2_scor
# Out:
# 0.6617883825700801
